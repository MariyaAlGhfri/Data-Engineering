# %% [markdown]
# # Netflix Userbase DataManipulation

# %% [markdown]
# # Objective
# "This data frame provides a snapshot of a sample Netflix userbase, showcasing various aspects of user subscriptions, revenue and account details. Each row represents a unique user, identified by their User ID. The dataset includes information such as the user's subscription type (Basic, Standard, or Premium), the monthly revenue generated from their subscription, the date they joined Netflix (Join Date), the date of their last payment (Last Payment Date), and the country in which they are located.
#
# Additional columns have been included to provide insights into user behavior and preferences. These columns include Device Type (e.g., Smart TV, Mobile, Desktop, Tablet),The dataset serves as a synthetic representation and does not reflect actual Netflix user data. It can be used for analysis and modeling to understand user trends, preferences, and revenue generation within a hypothetical Netflix userbase."
#
# You can find the dataset online in kaggle using the link below https://www.kaggle.com/datasets/arnavsmayan/netflix-userbase-dataset

# %% [markdown]
# # Read Data

# %%
import pandas as pd # import pandas library this library helps you to read dataframe and use the methods to extracrt data from it 
from pandas import Series, DataFrame 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from numpy.random import randn
import pandas as pd

# %%
#get and read the data as csv file
# you can let python open your csv(Excel) file and your dataset using the command pd.read_csv("FileName")
# now we have a variable called data_frame which refers to our uploaded csv(Excel) file and that helps us to 
#refer to it whenever we need and use it for manipulation purposes.
data_frame=pd.read_csv("Netflix.csv")

# %%
#to show the data frame just simply write down your data frame name 
data_frame
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14   25-07-22         12/7/2023
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
#
# ...

# %% [markdown]
# # Dataset Structure

# %%
#we can know the total numbers for rows (on the left) and the total number of columns(on the right) using the command "dataFrameName.shape"
data_frame.shape
# Out:
# (2500, 10)

# %%
#to know the overall information about the dataset you can use the command "dataFrameName.info()"
# look here you can find different information regarding your dataset as the number of columns, thier names and thier type , numbers of rows,
# and tells you if there is any null-value and in what column it maybe
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %% [markdown]
# # Extracting columns and rows

# %%
# We can grab all the columns names in the dataset using "dataFrameName.columns" command
data_frame.columns
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %%
# grabbing a specific column data using the command dataFrameName.['Coloumn Name']

data_frame['Subscription Type']

#Now we are able to see the all the records in column 'Subscription Type'
# Out:
# 0          Basic
# 1        Premium
# 2       Standard
# 3       Standard
# 4          Basic
#           ...
# 2495     Premium
# 2496       Basic
# 2497    Standard
# 2498    Standard
# 2499       Basic
# Name: Subscription Type, Length: 2500, dtype: object

# %%
# getting multiple columns' data at one go using below command DataFrame(dataFrameName,columns=['colOne', 'col Two','colThree',.....,'col n'])

DataFrame(data_frame,columns=['User ID', 'Subscription Type','Country', 'Age','Gender'])
# Out:
#       User ID Subscription Type         Country  Age  Gender
# 0           1             Basic   United States   28    Male
# 1           2           Premium          Canada   35  Female
# 2           3          Standard  United Kingdom   42    Male
# 3           4          Standard       Australia   51  Female
# 4           5             Basic         Germany   33    Male
# ...       ...               ...             ...  ...     ...
# 2496     2497             Basic           Spain   33  Female
# 2497     2498          Standard   United States   38    Male
# 2498     2499          Standard          Canada   48  Female
# 2499     2500             Basic   United States   35  Female
# 2500     2501           Premium            Oman   22  Female
#
# [2501 rows x 5 columns]

# %%
# Extracting the first 10 rows data from data frame using the command dataFrameName.head(numberOfRows)
data_frame.head(10)
# Out:
#    User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0        1             Basic               10   15-01-22         10/6/2023
# 1        2           Premium               15   5/9/2021          22-06-23
# 2        3          Standard               12   28-02-23          27-06-23
# 3        4          Standard               12  10/7/2022          26-06-23
# 4        5             Basic               10   1/5/2023          28-06-23
# 5        6           Premium               15   18-03-22          27-06-23
# 6        7          Standard               12  9/12/2021          25-06-23
# 7        8             Basic               10   2/4/2023          24-06-23
# 8        9          Standard               12   20-10-22          23-06-23
# 9       10           Premium               15   7/1/2023          22-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# ...

# %%
# Extracting the last 10 rows data from data frame using the command dataFrameName.tail(numberOfRows)
data_frame.tail(10)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 2490     2491           Premium               13   18-07-22         11/7/2023
# 2491     2492             Basic               14   19-07-22         12/7/2023
# 2492     2493          Standard               11   20-07-22         11/7/2023
# 2493     2494           Premium               12   21-07-22          15-07-23
# 2494     2495             Basic               15   23-07-22         12/7/2023
# 2495     2496           Premium               14   25-07-22         12/7/2023
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
#
#             Country  Age  Gender      Device Plan Duration
# ...

# %%
# Extracting a specific row/s data through the number of index of that row using dataFrameName.loc[row'sIndex] command


data_frame.loc[2]

#Here we are able to see the data regarding a row that's index is equal to 2 and you as a dataset viewer, can find the index of a row by
#looking at the left side of the dataset at a column before the UserID column which represents the index of each row and the count starts from 0.
# Out:
# User ID                            3
# Subscription Type           Standard
# Monthly Revenue                   12
# Join Date                   28-02-23
# Last Payment Date           27-06-23
# Country               United Kingdom
# Age                               42
# Gender                          Male
# Device                      Smart TV
# Plan Duration                1 Month
# First_Name_Country            United
# Last_Name_Country            Kingdom
# Name: 2, dtype: object

# %% [markdown]
# # Adding a new row and extracting rows

# %%
#Adding a new row
#We can add a new row by adding data into each column in dataset manually using the command 
#newRowName={'colOne':input,'col Tow':'input','colThree':input ,'col n ': input}

new_row={'User ID':2501,'Subscription Type':'Premium','Monthly Revenue':12,'Join Date' :'28-02-23','Last Payment Date':'27-06-23','Country':'Oman','Age':22,'Gender':'Female','Device':'Smart TV','Plan Duration':'1 Month'}
new_row
#To insert the new row you've made into your dataset you should use the command dataFrameName.loc[len(dataFrameName)]=newRowName
#Keep in mind that a new added row will automatically be added at the end of the dataset hence it will become the last row
data_frame.loc[len(data_frame)]=new_row

# %%
#checking upon the new added row
#As mentioned, the new added row will take the last row in dataset, we can check if it has been added using the
commnand dataFrameName.tail(1)
# 1 here means the first row from below the dataset
data_frame.tail(1)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2502     2501           Premium               12  28-02-23          27-06-23
#
#      Country  Age  Gender    Device Plan Duration First_Name_Country  \
# 2502    Oman   22  Female  Smart TV       1 Month                NaN
#
#      Last_Name_Country
# 2502               NaN

# %%
#Use the 'str.split()' method to split the column into two separate strings based on a delimiter. 
data_frame[['First_Name_Country', 'Last_Name_Country']] = data_frame['Country'].str.split(' ', 1, expand=True)
data_frame
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
# 2500     2501           Premium               12   28-02-23          27-06-23
#
# ...

# %%
# data can be filtered  by groupby command so the printed data frame will have data about users where users are only female 
grouped = data_frame.groupby(data_frame.Gender)
df_new = grouped.get_group("Female")
df_new
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 1           2           Premium               15   5/9/2021          22-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 5           6           Premium               15   18-03-22          27-06-23
# 7           8             Basic               10   2/4/2023          24-06-23
# 9          10           Premium               15   7/1/2023          22-06-23
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14   25-07-22         12/7/2023
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
# 2500     2501           Premium               12   28-02-23          27-06-23
#
# ...

# %%
# Extracting user data from data frame where they are from Australia(Country) and they are female(Gender) and they have premium Netflix account
data_frame[(data_frame['Gender']=='Female') & (data_frame['Country']=='Australia') & (data_frame['Subscription Type']=='Premium')]
# Out:
#       User ID Subscription Type  Monthly Revenue   Join Date  \
# 73         74           Premium               13    14-12-22
# 223       224           Premium               15    27-11-22
# 253       254           Premium               12    20-05-22
# 273       274           Premium               10    1/8/2022
# 283       284           Premium               14    4/8/2022
# 373       374           Premium               10   12/6/2022
# 393       394           Premium               14    30-05-22
# 413       414           Premium               14    21-08-22
# 423       424           Premium               12    18-09-22
# 433       434           Premium               12    15-10-22
# 443       444           Premium               10    25-06-22
# 583       584           Premium               14    14-07-22
# 673       674           Premium               13   10/6/2022
# 703       704           Premium               13    30-09-22
# ...

# %%
# data can be filtered  using below command so the printed data frame will have data of users whose 'monthly revenue' is 11 and above  
data_frame.loc[(data_frame["Monthly Revenue"]>=11)]
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 5           6           Premium               15   18-03-22          27-06-23
# 6           7          Standard               12  9/12/2021          25-06-23
# ...       ...               ...              ...        ...               ...
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
# 2500     2501           Premium               12   28-02-23          27-06-23
#
# ...

# %%
#Arranging Age column in ascending order can be done via below command
data_sorted = data_frame.sort_values('Age', ascending=True)
data_sorted['Age']
# Out:
# 2500    22
# 20      26
# 1045    27
# 1077    27
# 1081    27
#         ..
# 741     51
# 381     51
# 1251    51
# 2448    51
# 1161    51
# Name: Age, Length: 2501, dtype: int64

# %% [markdown]
# # droping missing values

# %%
#Drop all rows where NaN appear in a special column 'Subscription Type'
data_frame = data_frame[pd.notnull(data_frame['Subscription Type'])]
#Show data frame 
data_frame
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
# 2500     2501           Premium               12   28-02-23          27-06-23
#
# ...

# %%
#
data_frame.dropna(thresh=4)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
# 2500     2501           Premium               12   28-02-23          27-06-23
#
# ...

# %%
#We can use duplicated to find duplicates
data_frame.duplicated(['Subscription Type'])
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 2496     True
# 2497     True
# 2498     True
# 2499     True
# 2500     True
# Length: 2501, dtype: bool

# %%
#df['column name'] = df['column name'].replace(['old value'], 'new value')
data_frame['Device']=data_frame['Device'].replace(['Smartphone'],'Mobile')

data_frame
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
# 2500     2501           Premium               12   28-02-23          27-06-23
#
# ...

# %%
data_frame['Activity Status']="Active"
data_frame
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
# 2500     2501           Premium               12   28-02-23          27-06-23
#
# ...

# %%
del data_frame['Activity Status']
data_frame
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
# 2500     2501           Premium               12   28-02-23          27-06-23
#
# ...

# %%
data_frame['Country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Australia',
#        'Germany', 'France', 'Brazil', 'Mexico', 'Spain', 'Italy', 'Oman'],
#       dtype=object)

# %%
pd.crosstab(data_frame.Country,data_frame['Subscription Type'],margins=True)
# Out:
# Subscription Type  Basic  Premium  Standard   All
# Country
# Australia             31      101        51   183
# Brazil               146       33         4   183
# Canada               145       88        84   317
# France                36      147         0   183
# Germany              149        3        31   183
# Italy                176        4         3   183
# Mexico                 4        0       179   183
# Oman                   0        1         0     1
# Spain                110      212       129   451
# United Kingdom         3        0       180   183
# United States        199      145       107   451
# All                  999      734       768  2501

# %%
#
data_frame['Age'].describe()
# Out:
# count    2501.000000
# mean       38.788884
# std         7.178204
# min        22.000000
# 25%        32.000000
# 50%        39.000000
# 75%        45.000000
# max        51.000000
# Name: Age, dtype: float64

# %%
Q = (data_frame.groupby('Device'))
Q.describe()
# Out:
#          User ID                                                         \
#            count         mean         std  min     25%     50%      75%
# Device
# Laptop     636.0  1200.913522  710.778954  4.0  585.75  1191.0  1786.25
# Mobile     621.0  1225.409018  742.655360  1.0  564.00  1200.0  1874.00
# Smart TV   611.0  1290.090016  718.648782  3.0  662.00  1301.0  1931.50
# Tablet     633.0  1288.698262  713.803140  2.0  682.00  1311.0  1898.00
#
#                  Monthly Revenue             ...                Age  \
#              max           count       mean  ...   75%   max  count
# Device                                       ...
# Laptop    2498.0           636.0  12.569182  ...  14.0  15.0  636.0
# Mobile    2491.0           621.0  12.384863  ...  14.0  15.0  621.0
# Smart TV  2501.0           611.0  12.482815  ...  14.0  15.0  611.0
# Tablet    2499.0           633.0  12.592417  ...  14.0  15.0  633.0
#
#
#                mean       std   min   25%   50%   75%   max
# ...

# %% [markdown]
# # Visualizing Data
# To understand the relationship between data in dataset, graphing is one of the ways that used to get
# a visualized idea about that relationship.
# There are many types of graphs which can be used for plotting purposes, in this case we went with using the bar chart as it recommneded for categorical data type.

# %%
#Command below uses seaborn library(sns) method to generate auto count numbers on the y-axis depending on the length  of x-axis data.

#A box named as lenged with colours that represents one of the columns from a dataset indicates each bar/colour represents which observation.

#The legend will automatically replace itself wherever it is suatible for it however you can change the position of legend using the sns.move_legend() command.

#plt.show() is just to display the graph for you.
country_subsType_graph=sns.countplot(data= data_frame,  hue='Country',x='Subscription Type')
sns.move_legend(country_subsType_graph,"upper left",bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# This graph shows that the majority of users are subscribed to the 'Basic' subscription type. It maybe because the affordability of that plan. Adding to that, France takes the first place in terms of number of users subscribed to the 'Premium' subscription type. All in all, it is concluded that the 'Basic' and the 'Standard' subscription plan are most utilized comparing to the 'Premium' one. Although the 'Standard' and 'Premium' plans total users' numbers are slighly similar, however the 'Standard' users' number is greater.

# %%
sns.boxplot(x='Age', y='Device', data=data_frame,linewidth=1.5)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Device'>

# %%
pd.crosstab(data_frame['Age'],data_frame['Device'],margins=True)
# Out:
# Device  Laptop  Mobile  Smart TV  Tablet   All
# Age
# 22           0       0         1       0     1
# 26           1       0         0       0     1
# 27          21      21        27      18    87
# 28          31      30        26      28   115
# 29          20      26        23      35   104
# 30          26      25        32      33   116
# 31          27      24        25      39   115
# 32          24      18        31      19    92
# 33          20      28        24      21    93
# 34          21      24        23      20    88
# 35          30      31        20      24   105
# 36          24      23        28      24    99
# 37          28      21        29      29   107
# 38          27      23        16      23    89
# 39          24      36        31      25   116
# 40          23      32        23      25   103
# 41          39      33        17      25   114
# 42          33      26        20      23   102
# 43          30      21        22      21    94
# ...

# %%
pd.crosstab(data_frame['Subscription Type'],data_frame['Device'],margins=True)
# Out:
# Device             Laptop  Mobile  Smart TV  Tablet   All
# Subscription Type
# Basic                 259     251       238     251   999
# Premium               192     171       189     182   734
# Standard              185     199       184     200   768
# All                   636     621       611     633  2501

# %%
Age_Graph_kde=sns.kdeplot(data_frame['Age'])

# %%
Age_Graph=sns.countplot(data= data_frame,x='Age')

# %%
p=sns.jointplot(Age_Graph,Age_Graph_kde,kind='kde')
p.set_axis_labels("Data1", "Data2")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7988\3344463362.py in <module>
# ----> 1 p=sns.jointplot(Age_Graph,Age_Graph_kde,kind='kde')
#       2 p.set_axis_labels("Data1", "Data2")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.distplot(data_frame['Age'])
