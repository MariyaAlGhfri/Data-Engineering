# %%
import os

# %%
#getcwd()
cwd=os.getcwd()
cwd
# Out:
# 'C:\\Users\\user\\Desktop\\Mariya\\data engineering'

# %%
#os.chdir()
os.chdir('C:\\Users\\user\\Desktop\\Mariya')
cwd=os.getcwd()
print("directory changed")
cwd
# Out:
# directory changed
# 'C:\\Users\\user\\Desktop\\Mariya'

# %%
#os.listdir()
path=os.getcwd()
dir_list=os.listdir(path)
print('file and directorories ',path)
print(dir_list)
# Out:
# file and directorories  C:\Users\user\Desktop\Mariya
# ['add in githup.txt', 'code week 2', 'code week1', 'code week3', 'data engineering', 'Installation.docx', 'Untitled Folder', 'week5']

# %%
#os.walk() generte file nme in directory tree
path="C:\\Users\\user\\Desktop\\Mariya"
for (root,dirs,files) in os.walk(path, topdown=True):
    print(root)
    print(dirs)
    print(files)
# Out:
# C:\Users\user\Desktop\Mariya
# ['code week 2', 'code week1', 'code week3', 'data engineering', 'Untitled Folder', 'week5']
# ['add in githup.txt', 'Installation.docx']
# C:\Users\user\Desktop\Mariya\code week 2
# ['.git']
# ['avg.py', 'class.py', 'counter quation.py', 'day 14-5.py', 'day 15-5.py', 'day 16-5.py', 'day 17-5.py', 'day 18-5.py', 'day 21-5.py', 'day 22-5.py', 'day 23-5.py', 'day 24-5.py', 'day 25-5.py', 'list.docx', 'name', 'name.txt', 'q1.py', 'q1.txt', 'q2.py', 'q2.txt', 'qq.py']
# C:\Users\user\Desktop\Mariya\code week 2\.git
# ['hooks', 'info', 'objects', 'refs']
# ['config', 'description', 'HEAD', 'index']
# C:\Users\user\Desktop\Mariya\code week 2\.git\hooks
# []
# ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'update.sample']
# ...
